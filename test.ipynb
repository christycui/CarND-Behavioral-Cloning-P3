# %%
import cv2
import os

# %matplotlib inline
import matplotlib.pyplot as plt

path = "../../thunderhill/thunderhill_data/dataset_sim_004_km_320x160_cones_brakes/"
files = os.listdir(path+'IMG')
file = path+'IMG/center_2017_03_21_08_18_11_977.jpg'
img = cv2.imread(file)
plt.imshow(img)
